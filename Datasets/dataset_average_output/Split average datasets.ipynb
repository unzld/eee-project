# %%
import pandas as pd

df = pd.read_csv('dataset_average_noerror.csv')
d1 = df[(df['category'] == '1a') | (df['category'] == '1b')]
d2 = df[(df['category'] == '2a') | (df['category'] == '2b')]
d3 = df[(df['category'] == '3a') | (df['category'] == '3b')]
d4 = df[(df['category'] == '4a') | (df['category'] == '4b')]
d5 = df[(df['category'] == '5a') | (df['category'] == '5b')]
d6 = df[(df['category'] == '6a') | (df['category'] == '6b')]
d7 = df[(df['category'] == '7a') | (df['category'] == '7b')]

#d1.to_csv('d1_avg_error_adjustedloads.csv', index=False)
#d2.to_csv('d2_avg_error_adjustedloads.csv', index=False)
#d3.to_csv('d3_avg_error_adjustedloads.csv', index=False)
#d4.to_csv('d4_avg_error_adjustedloads.csv', index=False)
#d5.to_csv('d5_avg_error_adjustedloads.csv', index=False)
#d6.to_csv('d6_avg_error_adjustedloads.csv', index=False)
#d7.to_csv('d7_avg_error_adjustedloads.csv', index=False)

d1.to_csv('d1_avg.csv', index=False)
d2.to_csv('d2_avg.csv', index=False)
d3.to_csv('d3_avg.csv', index=False)
d4.to_csv('d4_avg.csv', index=False)
d5.to_csv('d5_avg.csv', index=False)
d6.to_csv('d6_avg.csv', index=False)
d7.to_csv('d7_avg.csv', index=False)

# %%
d1
# Out:
#      category      cm_1      cm_2      cm_3      cm_4      cm_5      cm_6  \
# 0          1a  4.078345  3.258020  3.560780  4.386091  3.480218  5.691918
# 1          1a  4.078345  3.258020  3.560780  4.386091  3.480218  5.691918
# 2          1a  3.893753  2.585338  3.355786  5.723069  3.783944  5.487495
# 3          1a  3.893753  2.585338  3.355786  5.723069  3.783944  5.487495
# 4          1a  4.220375  2.837118  3.243217  3.979658  3.539697  6.150716
# ...       ...       ...       ...       ...       ...       ...       ...
# 1535       1b  5.572375  6.361737  6.111365  8.622183  4.469656  8.689359
# 1536       1b  3.952999  6.485123  4.212793  7.120127  4.958014  7.785973
# 1537       1b  3.952999  6.485123  4.212793  7.120127  4.958014  7.785973
# 1538       1b  3.610072  4.739892  3.381319  7.167983  4.556846  8.139479
# 1539       1b  3.610072  4.739892  3.381319  7.167983  4.556846  8.139479
#
#           cm_7      cm_8  load_1_power  ...  load_47_power  load_48_power  \
# ...
